# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
import math
from sklearn.metrics import f1_score,accuracy_score,precision_score,recall_score
import heapq
import sys
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
df=pd.read_csv("English Dataset.csv")
df=df.drop(columns=["ArticleId"],axis=1)
#df["Category"]=df["Category"].astype('category').cat.codes

df.head()
# Out:
#                                                 Text  Category
# 0  worldcom ex-boss launches defence lawyers defe...  business
# 1  german business confidence slides german busin...  business
# 2  bbc poll indicates economic gloom citizens in ...  business
# 3  lifestyle  governs mobile choice  faster  bett...      tech
# 4  enron bosses in $168m payout eighteen former e...  business

# %%
Y=df["Category"]
X=df.drop(columns="Category",axis=1)

# %%
categories=["sport","business","tech","politics","entertainment"]
for x in categories:
    cat = df[df["Category"]==x]
    all_text = cat['Text'].str.cat(sep=' ')
    temp=all_text.split()
    counter=Counter(temp)
    print(counter)
# Out:
# Counter({'the': 6610, 'to': 3173, 'a': 2647, 'and': 2524, 'in': 2485, 'of': 1816, 's': 1432, 'i': 1302, 'for': 1122, 'he': 1104, 'on': 997, 'but': 992, 'is': 973, 'was': 940, 'it': 918, 'that': 826, 'have': 811, 'with': 800, 'at': 793, 'his': 762, 'we': 660, 'has': 648, 'be': 611, 'will': 575, 'as': 547, 'not': 485, 'from': 477, 'after': 475, 'by': 429, 'they': 414, 'had': 413, 'their': 381, 'been': 362, 'said': 356, 'are': 353, 'an': 351, 'this': 349, 'who': 323, 'first': 321, 't': 314, 'england': 313, 'against': 310, '-': 303, 'out': 295, 'when': 295, 'game': 285, 'win': 261, 'last': 255, 'if': 255, 'over': 254, 'two': 251, 'world': 248, 'all': 247, 'there': 246, 'she': 244, 'you': 239, 'would': 233, 'one': 230, 'up': 228, 'can': 228, 'were': 225, 'before': 224, 'her': 216, 'back': 215, 'also': 214, 'my': 198, 'new': 195, 'just': 192, 'cup': 192, 'time': 191, 'players': 190, 'm': 190, 'into': 184, 'ireland': 181, 'o': 181, 'play': 178, 'very': 176, 'what': 173, 'side': 172, 'only': 172, 'now': 171, 'could': 171, 'won': 170, 'wales': 169, 'six': 167, 'second': 165, 'good': 161, 'three': 160, 'which': 160, 'him': 159, 'so': 158, 'then': 157, 'said.': 155, 'team': 152, 'me': 149, 'year': 148, 'about': 147, 'made': 145, 'get': 144, 'chelsea': 144, 'match': 140, 'final': 136, 'coach': 135, 'france': 134, 'more': 132, 'great': 131, 'take': 129, 'some': 128, 'them': 127, 'off': 127, 'set': 125, 'club': 125, 'think': 125, 'said:': 123, 'told': 123, 'united': 121, 'well': 120, 'or': 119, 'like': 119, 'since': 118, 'next': 118, 'no': 117, 'still': 116, 'got': 116, 'open': 112, 'played': 112, 'international': 112, 've': 111, 'through': 111, 'start': 110, 'down': 110, 'make': 109, 'rugby': 109, 'going': 108, 'arsenal': 107, 'champion': 106, 'because': 106, 'us': 105, 'go': 104, 'do': 104, 'olympic': 101, 'injury': 100, 'ball': 100, 'games': 100, 'don': 100, 'minutes': 99, 'best': 99, 'am': 99, 'league': 99, 'nations': 97, 'our': 97, 'scotland': 97, 'than': 97, 'williams': 96, 'while': 96, 'playing': 95, 'right': 94, 'home': 93, 'both': 93, 'roddick': 93, 'season': 93, 'years': 92, 'victory': 91, 'four': 91, 'know': 91, 'v': 91, 'chance': 90, 'way': 90, 'five': 89, 'another': 89, 'jones': 89, 'any': 88, 'really': 87, 'other': 87, 'want': 86, 'should': 86, 'beat': 85, 'end': 85, 'top': 85, 'put': 85, 'former': 84, 'player': 84, 'grand': 83, 'lot': 83, 'left': 83, 'number': 82, 'champions': 82, 'winning': 81, 'did': 81, 'try': 80, 'took': 79, 'come': 78, 'manager': 78, 'd': 78, 'title': 77, 'week': 77, 'came': 76, 'see': 76, 'even': 76, 'liverpool': 76, 'australian': 75, 'face': 74, 'break': 72, 'being': 72, 'third': 71, 'boss': 71, 'robinson': 71, 'away': 71, 'goal': 70, 'during': 70, 'points': 69, 'didn': 69, 'return': 69, 'half': 67, 'better': 67, 'european': 67, 'game.': 66, 'never': 66, 'lost': 66, 'again': 65, 'football': 65, 'lead': 65, 'place': 65, 'italy': 64, 'give': 64, 'big': 64, 'bbc': 63, 'season.': 63, 'defeat': 62, 'referee': 62, 'j': 62, 'how': 61, 'mark': 61, 'seed': 61, 'where': 61, 'andy': 60, 'decision': 60, 'penalty': 59, 'much': 59, 'premiership': 59, 'early': 58, 'went': 58, 'ferguson': 58, 'missed': 58, 'nadal': 58, 'record': 57, 'manchester': 57, 'captain': 56, 'most': 56, 'tennis': 56, 'squad': 56, 'it.': 56, 'long': 56, 'people': 56, 'despite': 55, 'll': 55, 'under': 55, 'french': 55, 'round': 55, 'test': 55, 'holmes': 55, '.': 54, 'form': 54, 'zealand': 54, 'race': 54, 'g': 54, 'athens': 54, 'irish': 53, '10': 53, 'sunday': 53, 'real': 53, 'added:': 53, 'slam': 52, 're': 52, 'hard': 52, 'wenger': 52, 'forward': 52, 'britain': 52, 'days': 52, 'mourinho': 52, 'madrid': 52, 'training': 51, 'ahead': 50, 'run': 50, 'given': 50, 'indoor': 50, 'work': 50, 'scored': 50, 'saturday': 49, 'looking': 49, 'too': 49, 'career': 49, 'own': 49, 'pressure': 49, 'drugs': 49, 'says': 48, 'gara': 48, 'spain': 48, 'every': 48, 'event': 48, 'centre': 47, 'opening': 47, 'tour': 47, 'need': 47, 'between': 47, 'same': 47, 'many': 47, 'l ...
# Counter({'the': 7129, 'to': 3293, 'of': 2861, 'in': 2814, 'a': 2271, 'and': 2157, 's': 1350, 'is': 1069, 'that': 1047, 'for': 1039, 'it': 1001, 'on': 893, 'said': 876, 'has': 834, 'its': 736, 'by': 716, 'with': 605, 'as': 604, 'was': 596, 'at': 594, 'from': 588, 'be': 569, 'have': 553, 'are': 537, '-': 519, 'will': 518, 'us': 497, 'which': 403, 'mr': 393, 'but': 389, 'an': 385, 'had': 341, 'this': 317, 'would': 308, 'been': 307, 'year': 302, 'not': 296, 'more': 295, 'he': 287, 'up': 283, 'were': 282, 'also': 278, 'new': 273, 'than': 270, 'their': 265, 'firm': 242, 'company': 240, 'last': 235, 'market': 235, 'growth': 231, 'about': 228, 'after': 221, 'said.': 211, 'we': 210, 'government': 205, 'they': 204, 'economic': 202, 'could': 198, 'bank': 196, 'over': 190, 'economy': 189, 'sales': 184, 'may': 174, 'oil': 172, 'however': 163, 'one': 163, '000': 161, 'shares': 161, 'world': 160, 'some': 157, 'chief': 153, 'two': 151, 'now': 150, '2004': 148, 'if': 146, '.': 142, 'there': 141, 'or': 140, 'financial': 139, 'into': 136, 'while': 135, 'other': 135, 'uk': 134, 'business': 133, 'analysts': 133, 'deal': 132, 'out': 132, 'who': 131, 'companies': 130, 'china': 128, 'against': 127, 'prices': 123, 'expected': 119, 'his': 118, 'people': 117, 'rise': 115, 'three': 113, 'group': 113, 'years': 112, 'country': 112, 'many': 112, 'dollar': 112, 'since': 110, 'such': 109, 'yukos': 109, 'any': 108, 'year.': 108, 'india': 107, 'all': 105, 'still': 105, 'firms': 104, 'when': 104, 'between': 104, 'trade': 102, 'tax': 101, 'stock': 101, 'biggest': 100, 'told': 98, 'months': 98, 'interest': 98, 'no': 98, 'time': 96, 'profits': 95, 'president': 94, 'figures': 94, 'rates': 94, 'executive': 94, 'made': 94, 'only': 93, 'rate': 93, 'most': 93, 'european': 92, 'countries': 92, 'investment': 92, 'should': 92, 'spending': 91, 'first': 90, 'down': 90, 'foreign': 90, 'offer': 89, 'under': 88, 'strong': 88, 'set': 87, 'our': 86, 'recent': 86, '2005': 84, 'demand': 83, 'i': 83, 'money': 83, 'high': 82, 'december': 82, 'news': 81, 'according': 81, 'quarter': 80, 'price': 80, 'cut': 80, 'during': 79, 'rose': 79, 'state': 78, 'much': 78, 'being': 78, 'next': 77, 'likely': 77, 'both': 76, 'despite': 76, 'budget': 76, 'jobs': 76, 'can': 76, 'united': 76, 'increase': 75, 'back': 75, 'deficit': 75, 'south': 74, 'pay': 74, 'hit': 73, 'part': 73, 'former': 72, 'make': 72, 'europe': 71, 'well': 71, 'investors': 71, 'because': 71, 'share': 70, 'take': 70, 'london': 70, 'industry': 70, 'global': 68, 'russian': 68, 'exchange': 68, 'fall': 67, 'costs': 67, 'million': 67, 'month': 67, 'bid': 67, 'fell': 66, 'international': 66, 'club': 66, 'move': 66, 'eu': 66, 'record': 65, 'put': 65, 'debt': 65, 'bankruptcy': 64, 'sale': 64, 'giant': 63, 'week': 63, 'court': 63, 'euro': 62, 'these': 62, 'car': 62, 'plans': 62, 'report': 62, 'end': 62, 'january': 61, 'minister': 61, 'annual': 61, 'consumer': 61, 'say': 61, 'number': 61, 'just': 60, 'public': 60, 'current': 60, 'through': 59, 'need': 58, 'largest': 57, 'exports': 57, 'shareholders': 57, 'russia': 57, 'japan': 57, 'even': 56, 'seen': 56, 'euros': 56, 'profit': 56, 'boost': 56, 'continue': 55, 'higher': 55, 'further': 55, 'main': 54, 'less': 54, '2003': 54, 'stake': 54, 'off': 54, 'too': 54, 'fraud': 53, 'german': 53, 'those': 53, 'deutsche': 53, 'work': 53, 'finance': 52, 'agreed': 52, 'buy': 52, 'production': 52, 'previous': 52, 'airline': 52, 'indian': 52, 'earnings': 51, 'very': 51, 'before': 51, 'so': 51, 'trading': 51, 'lost': 51, 'unit': 51, 'already': 51, 'second': 51, 'talks': 51, 'do': 51, 'commission': 51, 'retail': 50, 'including': 50, 'national': 50, 't': 50, 'major': 50, 'good': 50, '2004.': 50, 'worldcom': 49, 'says': 49, 'november': 49, 'low': 49, 'years.': 49, 'get': 49, 'gm': 49, 'inflation': 48, 'markets': 48, 'added': 48, 'see': 48, 'although': 48, 'general': 48, 'did': 47, 'mci': 47, 'value': 47, 'development': 47, 'future': 47, 'help': 47, 'came': 47, 'takeover': 47, 'early': 46, 'latest': 46, '2005.': 46 ...
# Counter({'the': 7491, 'to': 4094, 'of': 3410, 'and': 3013, 'a': 2769, 'in': 2275, 'that': 1666, 'is': 1595, 'it': 1406, 'for': 1286, 'on': 1056, 'be': 1051, 'are': 990, 'as': 926, 'said': 815, 's': 805, 'will': 796, 'with': 781, 'by': 722, 'have': 718, 'has': 686, 'was': 652, 'they': 630, 'people': 624, 'more': 622, 'not': 530, 'at': 530, 'but': 527, 'which': 513, 'from': 498, 'he': 484, 'can': 475, 'this': 468, 'or': 450, 'their': 422, 'an': 408, 'its': 388, 'about': 366, 'new': 349, 'mr': 349, 'up': 348, 'also': 347, 'were': 344, 'you': 344, 'than': 341, '-': 338, 'we': 336, 'would': 321, 'one': 316, 'been': 312, 'mobile': 311, 'could': 308, 'there': 268, 'technology': 263, 'such': 263, 'other': 255, 'users': 249, 'out': 244, 'digital': 238, 'use': 237, 'what': 234, 'many': 234, 'music': 234, 'all': 230, 'net': 228, 'software': 223, 'some': 217, 'said.': 216, 'had': 214, 'if': 210, 'phone': 209, 'us': 209, 'make': 208, 'like': 205, 'i': 205, 'who': 204, 'so': 202, 'do': 200, 'games': 198, 'now': 192, 'over': 190, 'them': 188, 'when': 188, 'microsoft': 188, 'just': 186, 'into': 186, 'used': 180, 'service': 180, 'first': 179, 'get': 176, 'uk': 172, 'being': 172, 'most': 171, 'million': 171, 'how': 166, 'only': 164, 'way': 163, 'internet': 162, 'computer': 160, 'video': 160, 'year': 159, 'online': 157, 'because': 156, 'broadband': 155, 'world': 152, 'those': 150, 'tv': 150, 'game': 147, 'number': 144, 'services': 144, 'phones': 139, 'time': 139, 'very': 138, 'information': 138, 'search': 138, 'using': 135, 'according': 134, 'firms': 133, 'media': 133, 'security': 133, 'content': 128, 'data': 128, 'system': 128, 'much': 126, 'these': 126, 'two': 126, 'firm': 124, 'pc': 115, 'market': 115, 'web': 115, 'even': 114, 'take': 113, 'around': 112, 'own': 111, 'bbc': 111, 'no': 110, 'apple': 110, 'e-mail': 109, '000': 108, 'already': 108, 'work': 108, 'made': 108, 'any': 107, 'next': 107, 'last': 106, 'news': 105, 'says': 104, 'research': 103, 'well': 101, 'help': 100, 'she': 100, 'go': 99, 'companies': 99, 'your': 99, 'see': 98, 'going': 96, 'show': 96, 'want': 96, 'sony': 96, 'players': 96, 'consumers': 95, 'different': 95, 'site': 95, 'years': 94, 'part': 94, 'able': 93, 'home': 92, 'while': 91, 'then': 91, 'set': 90, 'his': 90, 'devices': 88, 'still': 88, 'should': 87, 'mobiles': 87, 'networks': 87, 'where': 86, 'company': 86, 'told': 85, 't': 85, 'three': 84, 'top': 84, 'consumer': 83, 'end': 82, '.': 82, 'virus': 82, 'good': 81, 'through': 81, 'europe': 80, 'gadget': 80, 'down': 80, 'radio': 80, 'industry': 79, 'google': 79, 'gadgets': 79, 'report': 78, 'access': 77, 'our': 76, 'every': 76, 'find': 76, 'may': 76, 'put': 76, 'european': 75, 'few': 75, 'network': 75, 'need': 75, 'windows': 75, 'bt': 74, 'found': 74, 'off': 74, 'spam': 74, 'portable': 74, 'technologies': 73, 'control': 72, 'gaming': 71, 'via': 71, 'likely': 71, 'messages': 70, 'version': 70, 'free': 70, 'small': 70, 'before': 70, 'sites': 70, 'play': 70, 'although': 69, 'offer': 69, '2004': 69, 'back': 69, 'become': 69, 'year.': 69, 'between': 68, 'hard': 68, 'say': 67, 'five': 66, 'months': 66, 'released': 66, 'customers': 65, 'camera': 65, 'several': 65, 'called': 65, 'really': 64, 'currently': 64, 'personal': 64, 'same': 63, 'did': 63, 'computers': 63, 'looking': 63, 'latest': 63, 'means': 63, 'mac': 63, 'player': 63, 'each': 62, 'machines': 62, 'come': 61, 'websites': 61, 'better': 60, 'popular': 60, 'almost': 60, 'device': 60, 'pcs': 60, 'available': 59, 'download': 59, 'programs': 59, 'machine': 59, '2': 59, 'big': 58, 'images': 58, 'both': 58, 'nintendo': 58, 'website': 58, 'systems': 57, 'after': 57, 'making': 57, 'group': 57, 'without': 57, 'attacks': 57, 'drive': 56, 'another': 56, 'growing': 56, 'look': 56, 'getting': 56, 'wireless': 56, 'my': 56, 'too': 55, 'does': 55, 'behind': 55, 'legal': 55, 'future': 55, 'electronics': 55, 'since': 55, 'power': 55, '10': 55, 'it.': 54, 'lot': 54, 'important': 54, 'entertainment': 54, 'something': 54, 'mean': 54, 'min ...
# Counter({'the': 7950, 'to': 3906, 'of': 2837, 'and': 2552, 'a': 2522, 'in': 2145, 'he': 1408, 'for': 1232, 'that': 1182, 'on': 1172, 'is': 1159, 'be': 1073, 'mr': 1071, 's': 1069, 'was': 1013, 'said': 971, 'it': 966, 'would': 710, 'as': 689, 'but': 668, 'have': 668, 'not': 650, 'by': 644, 'will': 640, 'with': 637, 'are': 630, 'has': 611, 'they': 570, 'at': 561, 'his': 538, '-': 501, 'labour': 469, 'from': 464, 'had': 461, 'government': 430, 'an': 429, 'we': 416, 'this': 397, 'i': 381, 'been': 376, 'were': 374, 'blair': 372, '.': 370, 'people': 361, 'there': 358, 'their': 357, 'which': 340, 'party': 334, 'who': 330, 'election': 317, 'also': 308, 'more': 289, 'if': 289, 'new': 280, 'about': 277, 'could': 272, 'said.': 271, 'minister': 265, 'brown': 251, 'up': 243, 'or': 228, 'all': 226, 'can': 225, 'uk': 223, 'should': 222, 'told': 216, 'over': 215, 'after': 215, 'what': 204, 'said:': 203, 'out': 202, 'public': 201, 'its': 200, 'prime': 194, 'no': 193, 'howard': 191, 'plans': 185, 'when': 183, 'being': 176, 'say': 169, 'secretary': 169, 'one': 167, 'you': 167, 'tory': 166, 'only': 165, 'tax': 164, 'general': 162, 'britain': 162, 'than': 162, 't': 161, 'some': 155, 'other': 152, 'leader': 151, 'into': 151, 'home': 150, 'next': 150, 'lord': 146, 'tories': 146, 'says': 145, 'chancellor': 144, 'bbc': 143, 'any': 142, 'do': 141, 'now': 139, 'two': 136, 'so': 135, 'tony': 133, 'lib': 133, 'she': 130, 'get': 130, 'our': 129, 'last': 128, 'make': 128, 'british': 128, 'before': 126, 'spokesman': 126, '000': 125, 'those': 123, 'bill': 123, 'because': 121, 'time': 118, 'police': 117, 'between': 117, 'campaign': 117, 'under': 116, 'made': 115, 'them': 115, 'first': 115, 'just': 114, 'liberal': 114, 'very': 113, 'against': 113, 'michael': 112, 'eu': 112, 'year': 111, 'council': 108, 'where': 105, 'local': 105, 'law': 104, 'take': 104, 'want': 103, 'how': 102, 'him': 99, 'many': 99, 'mps': 98, 'part': 97, 'ukip': 97, 'kennedy': 96, 'may': 94, 'political': 93, 'then': 90, 'work': 90, 'house': 89, 'way': 88, 'going': 88, 'years': 88, 'vote': 87, 'country': 87, 'us': 87, 'both': 86, 'such': 84, 'set': 84, 'foreign': 84, 'expected': 84, 'back': 84, 'good': 84, 'issue': 83, 'did': 83, 'these': 82, 'children': 82, 'parties': 82, 'former': 81, 'ministers': 81, 'believe': 81, 'help': 79, 'think': 78, 'like': 78, 'saying': 78, 'already': 78, 'election.': 78, 'while': 77, 'most': 77, 'european': 77, 'dems': 77, 'claims': 76, 'week': 76, 'immigration': 76, 'asylum': 76, 'put': 76, 'world': 75, 'office': 75, 'gordon': 74, 'increase': 74, 'london': 73, 'support': 72, 'men': 72, 'through': 72, 'voters': 72, 'without': 71, 'conservative': 70, 'need': 70, 'report': 70, 'change': 70, 'health': 70, 'commons': 69, 'pay': 69, 'don': 68, 'rights': 68, 'number': 67, 'national': 67, 'plan': 67, 'charles': 66, 'conservatives': 66, 'democrats': 66, 'during': 66, 'right': 65, 'iraq': 64, 'even': 64, 'kilroy-silk': 64, 'system': 64, 'see': 63, 'come': 63, 'human': 63, 'her': 63, 'go': 62, 'whether': 62, 'mp': 62, 'lords': 62, 'legal': 62, 'still': 62, 'down': 62, 'deal': 61, 'john': 61, 'own': 61, 'war': 60, 'use': 60, 'held': 60, 'shadow': 60, 'services': 60, 'called': 59, 'cabinet': 59, 'straw': 59, 'service': 59, 'give': 59, 'much': 59, 'policy': 59, 'used': 58, 'countries': 58, 'money': 58, 'four': 58, 'court': 58, 'taxes': 58, 'clear': 57, 'well': 57, 'schools': 57, 'evidence': 57, 'parliament': 56, 'news': 56, 'stand': 56, 'off': 56, 'dem': 56, 'three': 55, 'my': 55, 'since': 55, 'meeting': 55, 'david': 55, 'ms': 55, 'action': 54, 'given': 54, 'decision': 54, 'too': 54, 'place': 54, 'members': 54, 'spending': 53, 'minimum': 53, 'education': 53, 'commission': 52, 'budget': 52, 'move': 52, 'working': 52, 'role': 52, 'poll': 52, 'case': 52, 'chairman': 51, 'must': 51, 'powers': 51, 'issues': 51, 'power': 51, 'debate': 51, 'end': 51, 'trust': 51, 'committee': 50, 'chief': 50, 'clarke': 50, 'act': 50, 'day': 50, 'member': 49, 'affairs': 49, 'choice': 49, 'proposals':  ...
# Counter({'the': 5812, 'and': 2120, 'to': 2102, 'of': 2046, 'in': 1977, 'a': 1893, 's': 1243, 'for': 1094, 'on': 873, 'was': 818, 'it': 709, 'is': 682, 'with': 659, 'he': 583, 'at': 554, 'film': 506, 'be': 499, 'that': 486, 'as': 479, 'has': 471, '-': 464, 'his': 459, 'by': 458, 'will': 433, 'i': 421, 'best': 404, 'have': 383, 'said': 383, 'who': 358, 'from': 355, 'are': 330, 'but': 326, 'which': 305, 'an': 299, 'also': 277, 'been': 275, 'this': 263, 'had': 262, 'were': 261, 'one': 249, 'not': 249, 'they': 241, 'us': 240, 'she': 240, 'their': 235, 'we': 235, 'new': 232, 'music': 232, 'year': 213, 'her': 211, 'show': 187, 'after': 185, 'first': 184, 'more': 173, 'its': 171, 'up': 170, 'number': 165, 'won': 164, 'last': 159, 'actor': 158, 'uk': 157, 'band': 157, 'awards': 151, 'director': 148, 'mr': 148, 'all': 145, 'out': 145, 't': 144, 'other': 143, '.': 142, 'there': 142, 'star': 140, 'top': 138, 'would': 138, 'two': 137, 'tv': 135, 'said.': 134, 'or': 134, 'about': 134, 'when': 133, 'while': 130, 'british': 129, 'than': 129, 'you': 128, 'award': 123, 'films': 120, 'bbc': 120, 'people': 119, 'including': 115, 'three': 113, 'album': 109, 'actress': 109, 'into': 108, 'years': 106, 'singer': 102, 'made': 100, 'very': 98, 'time': 97, 'no': 96, 'my': 96, 'so': 96, 'stars': 93, 'million': 91, 'if': 91, 'now': 91, 'being': 89, 'do': 88, 'like': 87, 'comedy': 86, 'most': 86, 'festival': 84, 'oscar': 84, 'chart': 83, 'over': 83, 'just': 83, 'could': 82, 'such': 81, 'before': 81, 'movie': 81, 'record': 79, 'hit': 78, 'five': 78, 'musical': 78, 'world': 77, 'make': 77, 'said:': 77, 'song': 77, 'some': 76, 'well': 76, 'play': 76, 'london': 75, 'box': 74, 'sales': 74, 'big': 73, 'get': 73, 'took': 72, 'rock': 72, 'role': 71, 'hollywood': 70, '000': 70, '2004': 70, 'go': 70, 'series': 69, 'only': 68, 'them': 68, 'what': 67, 'single': 66, 'many': 66, 'can': 66, 'set': 65, 'him': 64, 'book': 64, 'place': 63, 'man': 63, 'drama': 63, 'second': 62, 'theatre': 62, 'academy': 62, 'told': 61, 'starring': 61, 'aviator': 61, 'went': 61, 'office': 60, 'during': 60, 'going': 60, 'm': 60, 'me': 60, 'pop': 59, 'because': 59, 'think': 59, 'four': 59, 'named': 59, 'nominated': 59, 'success': 58, 'life': 57, 'day': 57, 'win': 57, 'prize': 57, 'include': 56, 'group': 56, 'released': 56, 'children': 56, 'original': 56, 'since': 54, 'john': 54, 'ceremony': 54, 'nominations': 54, 'radio': 53, 'see': 53, 'former': 52, 'don': 52, 've': 52, 'take': 52, 'love': 52, 'among': 51, 'industry': 51, 'may': 50, 'company': 50, 'live': 50, 'should': 50, 'work': 49, 'our': 49, 'played': 49, 'week': 49, 'debut': 49, 'television': 49, 'later': 49, 'next': 49, 'charles': 49, 'against': 48, 'third': 48, 'good': 48, 'came': 48, 'version': 48, 'money': 48, 'how': 47, 'still': 47, 'got': 47, '10': 47, 'american': 47, 'did': 47, 'due': 47, 'ray': 47, 'christmas': 46, 'taking': 46, 'any': 46, 'audience': 45, 'following': 45, 'fans': 45, 'film.': 45, 'oscars': 45, 'great': 44, 'year.': 44, 'where': 44, 'shows': 44, 'around': 44, 'then': 44, 'home': 44, 'night': 44, 'golden': 44, 'paul': 43, 'singles': 43, 'sold': 43, 'really': 43, 'already': 43, 'release': 42, 'performance': 42, 'supporting': 42, 'want': 41, 're': 41, 'stage': 41, 'end': 41, 'never': 41, 'woman': 41, 'young': 41, 'part': 41, 'screen': 41, 'however': 40, 'included': 40, 'dance': 40, 'died': 40, 'story': 40, 'know': 40, 'become': 40, 'days': 40, 'down': 39, 'both': 39, 'much': 39, 'los': 39, 'back': 39, 'producers': 39, 'martin': 39, 'michael': 39, 'winners': 39, 'dollar': 39, 'jamie': 39, 'lee': 39, 'death': 38, 'biggest': 38, 'angeles': 38, 'held': 38, 'york': 38, 'vera': 38, '1': 37, 'off': 37, 'way': 37, 'career': 37, 'says': 37, 'winner': 37, 'elvis': 37, 'received': 36, 'according': 36, 'school': 36, 'producer': 36, 'special': 36, 'tour': 36, 'act': 36, 'drake': 36, 'despite': 35, 'seen': 35, 'digital': 35, 'songs': 35, 'saw': 35, 'found': 35, 'making': 35, '20': 35, 'artists': 35, 'list': 35, 'added': 35, 'actors ...

# %%
# Sports have england': 313 'game': 285  'win': 261
# Business has 'firm': 242 'company': 240 'market': 235
# Tech has 'mobile': 311 'technology': 263 'users': 249
# Politics has 'labour': 469 'government': 430 'blair': 372
# Entertainment has 'film': 506 'music': 232 'show': 187

# These are catergory specific apper most words according to me

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
def build_model(Vectorized_x,y_train,V,categories):
    # From a vector of words and Y_train finds the log values of the words
    labels_train = y_train.tolist() 
    log_likelihoods={}
    # Get log probs of each word in each class
    for cat in categories:
        indicies=[]
        for i in range(len(labels_train)):
            if labels_train[i]==cat:
                indicies.append(i)
        A_category = Vectorized_x[indicies]
        # Use +1 and V for smoothing
        word_counts_in_category = A_category.sum(axis=0) + 1
        total_words_in_category = A_category.sum() + V
        log_likelihoods_category = np.log(word_counts_in_category / total_words_in_category)
        log_likelihoods[cat] = log_likelihoods_category
    # Finds prior probs of classes
    log_priors = {}
    N = len(y_train) 
    category_counts_train = y_train.value_counts()
    for category_name in categories:
        Nc = category_counts_train.get(category_name, 0) 
        log_priors[category_name] = np.log((Nc + 1) / (N)) 
    return log_priors,log_likelihoods

# %% [markdown]
# This is the Naive Bias model after getting vectors

# %%
def predict(X_test_vectorized, log_priors, log_likelihoods):
    # After getting the probs of the words before , than for each new 
    # test case vector find the prob for each category than assigns it to max
    predictions = []
    
    for i in range(X_test_vectorized.shape[0]):
        # Vectorize current x
        doc_vector = X_test_vectorized[i] 
        scores = {}

        for cat in categories: 
            score = log_priors[cat] 
            # Get the log numbers from dict
            log_likelihoods_cat = log_likelihoods[cat]
            
            log_likelihoods_cat = np.array(log_likelihoods_cat).flatten()


            for word_index, word_count in zip(doc_vector.indices, doc_vector.data):
                
                if word_index < log_likelihoods_cat.shape[0]:
                   # Adding the probs becouse of log
                   score += word_count * log_likelihoods_cat[word_index] 
                   
            scores[cat] = score 

        predicted_category = max(scores, key=scores.get)
        predictions.append(predicted_category)
        
    return predictions

# %%
# Most basic model with count_Vectorizer and 1 word without any changes
corpus = X_train['Text'] 
vectorizer = CountVectorizer()
A = vectorizer.fit_transform(corpus)
vocabulary = vectorizer.get_feature_names_out()
V = len(vocabulary)
log_priors,log_likelihoods = build_model(A,y_train,V,categories)

# %%
X_test_texts = X_test['Text']
X_test_vec = vectorizer.transform(X_test_texts)
pred=predict(X_test_vec,log_priors,log_likelihoods)
print(pred)
# Out:
# ['tech', 'politics', 'politics', 'tech', 'tech', 'business', 'tech', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'business', 'sport', 'tech', 'politics', 'business', 'sport', 'politics', 'business', 'tech', 'entertainment', 'sport', 'business', 'sport', 'tech', 'business', 'sport', 'tech', 'business', 'sport', 'business', 'business', 'politics', 'sport', 'tech', 'politics', 'business', 'entertainment', 'tech', 'sport', 'business', 'politics', 'business', 'sport', 'business', 'politics', 'tech', 'politics', 'business', 'sport', 'sport', 'business', 'sport', 'politics', 'entertainment', 'entertainment', 'politics', 'business', 'entertainment', 'tech', 'business', 'entertainment', 'tech', 'tech', 'tech', 'business', 'tech', 'politics', 'politics', 'politics', 'sport', 'sport', 'sport', 'entertainment', 'entertainment', 'business', 'politics', 'business', 'business', 'business', 'sport', 'sport', 'sport', 'business', 'entertainment', 'sport', 'business', 'business', 'tech', 'entertainment', 'business', 'politics', 'tech', 'business', 'politics', 'tech', 'tech', 'entertainment', 'politics', 'entertainment', 'politics', 'entertainment', 'sport', 'tech', 'sport', 'politics', 'sport', 'business', 'tech', 'tech', 'business', 'tech', 'entertainment', 'tech', 'business', 'politics', 'business', 'entertainment', 'business', 'politics', 'sport', 'business', 'politics', 'business', 'business', 'tech', 'tech', 'politics', 'entertainment', 'business', 'sport', 'entertainment', 'sport', 'business', 'politics', 'business', 'entertainment', 'business', 'entertainment', 'business', 'entertainment', 'tech', 'sport', 'entertainment', 'politics', 'business', 'tech', 'politics', 'politics', 'sport', 'business', 'tech', 'sport', 'entertainment', 'tech', 'tech', 'sport', 'tech', 'sport', 'sport', 'politics', 'business', 'tech', 'politics', 'politics', 'tech', 'sport', 'sport', 'tech', 'politics', 'tech', 'tech', 'entertainment', 'business', 'tech', 'entertainment', 'sport', 'business', 'business', 'sport', 'sport', 'tech', 'entertainment', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'politics', 'sport', 'sport', 'politics', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'entertainment', 'politics', 'sport', 'entertainment', 'business', 'sport', 'tech', 'tech', 'business', 'business', 'sport', 'politics', 'business', 'entertainment', 'sport', 'politics', 'politics', 'sport', 'tech', 'politics', 'sport', 'tech', 'business', 'business', 'entertainment', 'tech', 'business', 'politics', 'politics', 'politics', 'politics', 'sport', 'sport', 'business', 'business', 'tech', 'business', 'sport', 'sport', 'politics', 'politics', 'entertainment', 'entertainment', 'entertainment', 'business', 'business', 'entertainment', 'entertainment', 'sport', 'entertainment', 'sport', 'politics', 'tech', 'sport', 'politics', 'tech', 'entertainment', 'sport', 'tech', 'business', 'business', 'politics', 'tech', 'tech', 'tech', 'sport', 'sport', 'business', 'politics', 'entertainment', 'sport', 'sport', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'politics', 'entertainment', 'business', 'business', 'politics', 'business', 'business', 'business', 'tech', 'politics', 'entertainment', 'business', 'business', 'business', 'business', 'politics', 'entertainment', 'tech', 'entertainment']

# %%
# Bigram vectorizer ngram_range=(2,2) to get 2 words
corpus = X_train['Text'] 
vectorizer_bigram = CountVectorizer(ngram_range=(2,2)) 
A_bigram = vectorizer_bigram.fit_transform(corpus)
vocabulary_bigram = vectorizer_bigram.get_feature_names_out()
V_bigram = len(vocabulary_bigram)
log_priors_bigram, log_likelihoods_bigram = build_model(A_bigram, y_train, V_bigram, categories)

# %%
X_test_vec_bigram = vectorizer_bigram.transform(X_test_texts) 
pred_bigram = predict(X_test_vec_bigram, log_priors_bigram, log_likelihoods_bigram)

# %%
results = {}

for category_name in categories:
    print(category_name)

    log_likelihood_array = np.array(log_likelihoods[category_name]).flatten()
    
    sorted_indices = np.argsort(log_likelihood_array)
    
    top_10_indices = sorted_indices[-10:][::-1]
    top_10_words = vocabulary[top_10_indices]
    top_10_values = log_likelihood_array[top_10_indices]
    
    bottom_10_indices = sorted_indices[:10]
    bottom_10_words = vocabulary[bottom_10_indices]
    bottom_10_values = log_likelihood_array[bottom_10_indices]
    
    print("BEST: ",top_10_words)
    print("WORST: ",bottom_10_words)
    print()
# Out:
# sport
# BEST:  ['the' 'to' 'in' 'and' 'of' 'for' 'he' 'on' 'is' 'but']
# WORST:  ['0001' '000bn' 'zillion' 'zip' 'ziyi' 'zodiac' 'zombie' '0400' '041'
#  'zoe']
#
# business
# BEST:  ['the' 'to' 'of' 'in' 'and' 'said' 'is' 'that' 'for' 'it']
# WORST:  ['zorro' 'zooropa' 'zooms' 'zoom' 'zonealarm' 'zeppelin' '0400' '04secs'
#  '050505' '0530']
#
# tech
# BEST:  ['the' 'to' 'of' 'and' 'in' 'that' 'is' 'it' 'for' 'on']
# WORST:  ['zurich' 'zuluaga' 'zorro' 'zooropa' 'zeppelin' 'zeta' 'zhang' 'zhaoxing'
#  '050' '050505']
#
# politics
# BEST:  ['the' 'to' 'of' 'and' 'in' 'said' 'he' 'for' 'that' 'is']
# WORST:  ['zurich' 'zuluaga' 'zorro' 'zooropa' 'zooms' 'zoom' 'zones' 'zonealarm'
#  'zombies' 'zeppelin']
#
# entertainment
# BEST:  ['the' 'and' 'to' 'of' 'in' 'for' 'on' 'was' 'it' 'is']
# WORST:  ['04secs' '050' '001' '001and' '0051' '01' '028' '03' 'zhaoxing' 'zheng']

# %% [markdown]
# Same words with best since all the stopwords are in all classes.
#
# Worst are also similar since those words are very specific but not specific to class.

# %%
# Vectorizer with TD IDF
corpus = X_train['Text'] 
vectorizer = CountVectorizer()
A = vectorizer.fit_transform(corpus)
vocabulary = vectorizer.get_feature_names_out()
V = len(vocabulary)
# Using unigram fit it into TFs
TF=TfidfTransformer().fit_transform(A)
log_priors_tf,log_likelihoods_tf = build_model(TF,y_train,V,categories)
pred_tf=predict(X_test_vec,log_priors_tf,log_likelihoods_tf)
print(pred)
# Out:
# ['tech', 'politics', 'politics', 'tech', 'tech', 'business', 'tech', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'business', 'sport', 'tech', 'politics', 'business', 'sport', 'politics', 'business', 'tech', 'entertainment', 'sport', 'business', 'sport', 'tech', 'business', 'sport', 'tech', 'business', 'sport', 'business', 'business', 'politics', 'sport', 'tech', 'politics', 'business', 'entertainment', 'tech', 'sport', 'business', 'politics', 'business', 'sport', 'business', 'politics', 'tech', 'politics', 'business', 'sport', 'sport', 'business', 'sport', 'politics', 'entertainment', 'entertainment', 'politics', 'business', 'entertainment', 'tech', 'business', 'entertainment', 'tech', 'tech', 'tech', 'business', 'tech', 'politics', 'politics', 'politics', 'sport', 'sport', 'sport', 'entertainment', 'entertainment', 'business', 'politics', 'business', 'business', 'business', 'sport', 'sport', 'sport', 'business', 'entertainment', 'sport', 'business', 'business', 'tech', 'entertainment', 'business', 'politics', 'tech', 'business', 'politics', 'tech', 'tech', 'entertainment', 'politics', 'entertainment', 'politics', 'entertainment', 'sport', 'tech', 'sport', 'politics', 'sport', 'business', 'tech', 'tech', 'business', 'tech', 'entertainment', 'tech', 'business', 'politics', 'business', 'entertainment', 'business', 'politics', 'sport', 'business', 'politics', 'business', 'business', 'tech', 'tech', 'politics', 'entertainment', 'business', 'sport', 'entertainment', 'sport', 'business', 'politics', 'business', 'entertainment', 'business', 'entertainment', 'business', 'entertainment', 'tech', 'sport', 'entertainment', 'politics', 'business', 'tech', 'politics', 'politics', 'sport', 'business', 'tech', 'sport', 'entertainment', 'tech', 'tech', 'sport', 'tech', 'sport', 'sport', 'politics', 'business', 'tech', 'politics', 'politics', 'tech', 'sport', 'sport', 'tech', 'politics', 'tech', 'tech', 'entertainment', 'business', 'tech', 'entertainment', 'sport', 'business', 'business', 'sport', 'sport', 'tech', 'entertainment', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'politics', 'sport', 'sport', 'politics', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'entertainment', 'politics', 'sport', 'entertainment', 'business', 'sport', 'tech', 'tech', 'business', 'business', 'sport', 'politics', 'business', 'entertainment', 'sport', 'politics', 'politics', 'sport', 'tech', 'politics', 'sport', 'tech', 'business', 'business', 'entertainment', 'tech', 'business', 'politics', 'politics', 'politics', 'politics', 'sport', 'sport', 'business', 'business', 'tech', 'business', 'sport', 'sport', 'politics', 'politics', 'entertainment', 'entertainment', 'entertainment', 'business', 'business', 'entertainment', 'entertainment', 'sport', 'entertainment', 'sport', 'politics', 'tech', 'sport', 'politics', 'tech', 'entertainment', 'sport', 'tech', 'business', 'business', 'politics', 'tech', 'tech', 'tech', 'sport', 'sport', 'business', 'politics', 'entertainment', 'sport', 'sport', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'politics', 'entertainment', 'business', 'business', 'politics', 'business', 'business', 'business', 'tech', 'politics', 'entertainment', 'business', 'business', 'business', 'business', 'politics', 'entertainment', 'tech', 'entertainment']

# %%
# Using stop words with unigram stop_words="english"
corpus = X_train['Text'] 
vectorizer_stop = CountVectorizer(stop_words="english") 
A_stop = vectorizer_stop.fit_transform(corpus)
vocabulary_stop = vectorizer_stop.get_feature_names_out()
V_stop = len(vocabulary_stop)
log_priors_stop, log_likelihoods_stop = build_model(A_stop, y_train, V_stop, categories)
X_test_texts = X_test['Text'] 
X_test_vec_stop = vectorizer_stop.transform(X_test_texts) 
pred_stop = predict(X_test_vec_stop, log_priors_stop, log_likelihoods_stop)

# %%
# Bigram with stopwords
corpus = X_train['Text'] 
vectorizer_stop_bi = CountVectorizer(stop_words="english",ngram_range=(2,2))
A_stop_bi = vectorizer_stop_bi.fit_transform(corpus)
vocabulary_stop_bi = vectorizer_stop_bi.get_feature_names_out()
V_stop_bi = len(vocabulary_stop_bi)
log_priors_stop_bi,log_likelihoods_stop_bi = build_model(A_stop_bi,y_train,V_stop_bi,categories)
X_test_texts = X_test['Text'] 
X_test_vec_stop = vectorizer_stop_bi.transform(X_test_texts) 
pred_stop_bi=predict(X_test_vec_stop,log_priors_stop_bi,log_likelihoods_stop_bi)

# %%
# Stopwords with TF
corpus = X_train['Text'] 
vectorizer_TF_stop = CountVectorizer(stop_words="english")
A_stop_tf = vectorizer_TF_stop.fit_transform(corpus)
vocabulary_tf_bi = vectorizer_TF_stop.get_feature_names_out()
V_stop_tf = len(vocabulary_tf_bi)
# Using unigram fit it into TFs
TF_stop=TfidfTransformer().fit_transform(A_stop_tf)
log_priors_tf_stop,log_likelihoods_tf_stop = build_model(TF_stop,y_train,V_stop_tf,categories)
X_test_texts = X_test['Text'] 
X_test_vec_stop = vectorizer_TF_stop.transform(X_test_texts) 
pred_tf_stop=predict(X_test_vec_stop,log_priors_tf_stop,log_likelihoods_tf_stop)
print(pred)
# Out:
# ['tech', 'politics', 'politics', 'tech', 'tech', 'business', 'tech', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'business', 'sport', 'tech', 'politics', 'business', 'sport', 'politics', 'business', 'tech', 'entertainment', 'sport', 'business', 'sport', 'tech', 'business', 'sport', 'tech', 'business', 'sport', 'business', 'business', 'politics', 'sport', 'tech', 'politics', 'business', 'entertainment', 'tech', 'sport', 'business', 'politics', 'business', 'sport', 'business', 'politics', 'tech', 'politics', 'business', 'sport', 'sport', 'business', 'sport', 'politics', 'entertainment', 'entertainment', 'politics', 'business', 'entertainment', 'tech', 'business', 'entertainment', 'tech', 'tech', 'tech', 'business', 'tech', 'politics', 'politics', 'politics', 'sport', 'sport', 'sport', 'entertainment', 'entertainment', 'business', 'politics', 'business', 'business', 'business', 'sport', 'sport', 'sport', 'business', 'entertainment', 'sport', 'business', 'business', 'tech', 'entertainment', 'business', 'politics', 'tech', 'business', 'politics', 'tech', 'tech', 'entertainment', 'politics', 'entertainment', 'politics', 'entertainment', 'sport', 'tech', 'sport', 'politics', 'sport', 'business', 'tech', 'tech', 'business', 'tech', 'entertainment', 'tech', 'business', 'politics', 'business', 'entertainment', 'business', 'politics', 'sport', 'business', 'politics', 'business', 'business', 'tech', 'tech', 'politics', 'entertainment', 'business', 'sport', 'entertainment', 'sport', 'business', 'politics', 'business', 'entertainment', 'business', 'entertainment', 'business', 'entertainment', 'tech', 'sport', 'entertainment', 'politics', 'business', 'tech', 'politics', 'politics', 'sport', 'business', 'tech', 'sport', 'entertainment', 'tech', 'tech', 'sport', 'tech', 'sport', 'sport', 'politics', 'business', 'tech', 'politics', 'politics', 'tech', 'sport', 'sport', 'tech', 'politics', 'tech', 'tech', 'entertainment', 'business', 'tech', 'entertainment', 'sport', 'business', 'business', 'sport', 'sport', 'tech', 'entertainment', 'entertainment', 'business', 'tech', 'politics', 'entertainment', 'politics', 'sport', 'sport', 'politics', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'entertainment', 'politics', 'sport', 'entertainment', 'business', 'sport', 'tech', 'tech', 'business', 'business', 'sport', 'politics', 'business', 'entertainment', 'sport', 'politics', 'politics', 'sport', 'tech', 'politics', 'sport', 'tech', 'business', 'business', 'entertainment', 'tech', 'business', 'politics', 'politics', 'politics', 'politics', 'sport', 'sport', 'business', 'business', 'tech', 'business', 'sport', 'sport', 'politics', 'politics', 'entertainment', 'entertainment', 'entertainment', 'business', 'business', 'entertainment', 'entertainment', 'sport', 'entertainment', 'sport', 'politics', 'tech', 'sport', 'politics', 'tech', 'entertainment', 'sport', 'tech', 'business', 'business', 'politics', 'tech', 'tech', 'tech', 'sport', 'sport', 'business', 'politics', 'entertainment', 'sport', 'sport', 'tech', 'sport', 'sport', 'politics', 'sport', 'sport', 'business', 'politics', 'entertainment', 'business', 'business', 'politics', 'business', 'business', 'business', 'tech', 'politics', 'entertainment', 'business', 'business', 'business', 'business', 'politics', 'entertainment', 'tech', 'entertainment']

# %%
results = {}

for category_name in categories:
    print(category_name)
    log_likelihood_array = np.array(log_likelihoods_stop[category_name]).flatten()
    
    sorted_indices = np.argsort(log_likelihood_array)
    
    top_10_indices = sorted_indices[-10:][::-1]
    top_10_words = vocabulary[top_10_indices]
    top_10_values = log_likelihood_array[top_10_indices]
    
    bottom_10_indices = sorted_indices[:10]
    bottom_10_words = vocabulary[bottom_10_indices]
    bottom_10_values = log_likelihood_array[bottom_10_indices]
    
    print("BEST: ",top_10_words)
    print("WORST: ",bottom_10_words)
    print()
# Out:
# sport
# BEST:  ['rose' 'fujitsu' 'enables' 'wilson' 'terminal' 'wentworth' 'wars' 'naris'
#  'crucially' 'job']
# WORST:  ['0400' '041' '050' '050505' '0530' '001st' '0051' '007' '0100' '0130']
#
# business
# BEST:  ['rose' 'wilson' 'money' 'naris' 'figo' 'maldives' 'grassroot'
#  'commanding' 'earlier' 'glorious']
# WORST:  ['wooden' 'woodbridge' 'wood' 'wonky' 'wolf' 'wolfgang' 'wolfram' 'wolpaw'
#  '050505' '0530']
#
# tech
# BEST:  ['rose' 'partner' 'millar' 'money' 'naris' 'swiss' 'wilson' 'skidelsky'
#  'undulating' 'unemployment']
# WORST:  ['03' 'wolf' 'wolfgang' 'wolfram' 'wolpaw' 'nandrolone' 'nanoscale'
#  'nanotechnology' 'naoki' 'nadu']
#
# politics
# BEST:  ['rose' 'money' 'kirby' 'glorious' 'editing' 'biological' 'partner'
#  'owning' 'metatarsal' 'treason']
# WORST:  ['0530' '050' '05' '04secs' '041' '0400' '033' '03' '0130' '0100']
#
# entertainment
# BEST:  ['rose' 'feroz' 'bennett' 'wilson' 'motherboards' 'naris' 'avenue'
#  'activists' 'webster' 'treason']
# WORST:  ['wong' 'peter' 'peterhead' 'wolfram' 'wolpaw' 'wolstenholme' 'wolves'
#  'peters' 'petersen' 'wombling']

# %% [markdown]
# Using stop words are meaningles for the most part since they are almost used in every context without giveing context. So it is just slowing down the training and doest give much information. The new words are have much more meaning.

# %%
acc = accuracy_score(y_test,pred)
print(f"Normal accu: {acc}")
f1 = f1_score(y_test,pred,average="weighted")
print(f"Normal f1: {f1}")
# Out:
# Normal accu: 0.9765100671140939
# Normal f1: 0.9765452996043319

# %%
acc_bigram = accuracy_score(y_test, pred_bigram)
print(f"Bigram Acc: {acc_bigram}")
f1_bigram = f1_score(y_test, pred_bigram, average="weighted")
print(f"Bigram F1: {f1_bigram}")
# Out:
# Bigram Acc: 0.9731543624161074
# Bigram F1: 0.9733343931508186

# %%
acc = accuracy_score(y_test,pred_tf)
print(f"TF IDF ACC: {acc}")
f1 = f1_score(y_test,pred_tf,average="weighted")
print(f"TF IDF F1: {f1}")
# Out:
# TF IDF ACC: 0.9295302013422819
# TF IDF F1: 0.928621714775582

# %%
acc_stop = accuracy_score(y_test, pred_stop)
print(f"Stop Words Uni Accuracy: {acc_stop}")
f1_stop = f1_score(y_test, pred_stop, average="weighted")
print(f"Stop Words Uni F1: {f1_stop}")
# Out:
# Stop Words Uni Accuracy: 0.9765100671140939
# Stop Words Uni F1: 0.9764795084886346

# %%
acc_stop_bi = accuracy_score(y_test, pred_stop_bi)
print(f"Stop Words Bigram Accuracy: {acc_stop_bi}")
f1_stop_bi = f1_score(y_test, pred_stop_bi, average="weighted")
print(f"Stop Words Bigram F1: {f1_stop_bi}")
# Out:
# Stop Words Bigram Accuracy: 0.959731543624161
# Stop Words Bigram F1: 0.959914515726645

# %%
acc_stop_tf = accuracy_score(y_test, pred_tf_stop)
print(f"Stop Words TF Accuracy: {acc_stop_tf}")
f1_stop_tf = f1_score(y_test, pred_tf_stop, average="weighted")
print(f"Stop Words TF F1: {f1_stop_tf}")
# Out:
# Stop Words TF Accuracy: 0.9697986577181208
# Stop Words TF F1: 0.969936956003185

# %% [markdown]
# Stop words imporved performance in every case . Using bigram dint give any big improvement and TF give a bit worse results.
